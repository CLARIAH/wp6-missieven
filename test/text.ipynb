# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use('missieven:clone', checkout="clone", hoist=globals())
# Out:
# <b title="local github">TF-app:</b> <span title="repo clone offline under ~/github">~/github/annotation/app-missieven/code</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/Dans-labs/clariah-gm/tf/0.4</span>
# ...

# %%
F.otype.s("line")
# Out:
# range(823, 891)

# %%
page = T.nodeFromSection((4, 239))
page
# Out:
# 5502481

# %%
for ln in L.d(page, otype="line"):
    print(ln)
    for w in L.d(ln, otype="word"):
        print(f"\t{w} [{F.trans.v(w)}]")
# Out:
# 5165824
# 	1184451 [IV]
# 	1184452 [RYCKLOFF]
# 	1184453 [VAN]
# 	1184454 [GOENS]
# 	1184455 [CORNELIS]
# 	1184456 [SPEELMAN]
# 	1184457 [WILLEM]
# 	1184458 [VAN]
# 5165825
# 	1184459 [OUTHOORN]
# 	1184460 [JOANNES]
# 	1184461 [CAMPHUYS]
# 	1184462 [EN]
# 	1184463 [JACOB]
# 	1184464 [PITS]
# 	1184465 [BATAVIA]
# 	1184466 [3]
# 	1184467 [augustus]
# 5165826
# 	1184468 [1678]
# 5165827
# 	1184469 [1212]
# 	1184470 [fol]
# 	1184471 [699]
# 	1184472 [706]
# 	1184473 [copie]
# 	1184474 [1220]
# 	1184475 [fol]
# 	1184476 [96]
# 	1184477 [109]
# 5165828
# 	1184478 []
# 5165829
# 	1184479 [Vgl]
# 	1184480 [Daghregisters]
# 	1184481 [1678]
# 	1184482 [p]
# 	1184483 [189]
# 	1184484 [421]
# 	1184485 [het]
# 	1184486 [huurschip]
# 	1184487 [St]
# 	1184488 [Andries]
# 	1184489 [kwam]
# 	1184490 [in]
# 5165830
# 	1184491 [slechte]
# 	1184492 [staat]
# 	1184493 [uit]
# 	1184494 [patria]
# 	1184495 [te]
# 	1184496 [Batavia]
# 	1184497 [en]
# 	1184498 [wordX]
# 	1184499 [op]
# 	1184500 [Onrust]
# ...
